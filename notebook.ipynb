# %%
# Parse the data
with open('dc_op_pt.txt') as f:
    data_raw = []
    for line in f:
        data_raw.append(line.split()[0:2])
        print(line.split()[0:2])
# Out:
# ['V(n002):', '1.05385']
# ['V(n001):', '1.8']
# ['V(vref_in):', '1.25']
# ['V(x1:n001):', '1.55916']
# ['V(x1:n004):', '0.627915']
# ['V(x1:n002):', '1.55817']
# ['V(vref_out):', '1.25017']
# ['V(x1:n003):', '1.29251']
# ['V(x1:bias_m3_m4):', '0.801006']
# ['V(x1:bias_nmos):', '0.704914']
# ['V(x1:n005):', '0.0252345']
# ['V(x1:n006):', '0.0251622']
# ['Id(x1:M15):', '5.15832e-005']
# ['Ig(x1:M15):', '0']
# ['Ib(x1:M15):', '-8.11006e-013']
# ['Is(x1:M15):', '-5.15832e-005']
# ['Id(x1:M14):', '5.11234e-005']
# ['Ig(x1:M14):', '0']
# ['Ib(x1:M14):', '-7.14914e-013']
# ['Is(x1:M14):', '-5.11234e-005']
# ['Id(x1:M12):', '5.07343e-005']
# ['Ig(x1:M12):', '0']
# ['Ib(x1:M12):', '-6.37915e-013']
# ['Is(x1:M12):', '-5.07343e-005']
# ['Id(x1:M8):', '2.00119e-005']
# ['Ig(x1:M8):', '0']
# ['Ib(x1:M8):', '-3.13822e-014']
# ['Is(x1:M8):', '-2.00119e-005']
# ['Id(x1:M7):', '2.00678e-005']
# ['Ig(x1:M7):', '0']
# ['Ib(x1:M7):', '-3.1465e-014']
# ['Is(x1:M7):', '-2.00678e-005']
# ...

# %%
#
